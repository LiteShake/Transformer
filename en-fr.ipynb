# %%
import pandas as pd

# %%
df = pd.read_csv("./datasets/en-fr.csv", chunksize=1000)

# %%
start = "<START>"
flip = "<LFLIP>"
end = "<END>"

# %%
string = ""

# %%
data["en"]
# Out:
# 11000    An industry consortium was formed in 1996 [the...
# 11001    • Attempts to manipulate the gonad inhibiting ...
# 11002    Food processing Biotechnology has been used in...
# 11003    Food biotechnology is being used to enhance fo...
# 11004    However, most of this work involves first gene...
#                                ...
# 11995    These four countries supplied 96% of total imp...
# 11996    Key Players There are approximately 150 compan...
# 11997    The major firms involved in the production and...
# 11998                        (CMC) and Sysu International.
# 11999    Major Players in the fruits spreads market Com...
# Name: en, Length: 1000, dtype: object

# %%
data = next(df)
rows = 0

while(not data.empty and rows < 10_000):
    
    for i in range(data.shape[0]):
        
        try:
            string = start + data["en"][rows].strip() + flip + data["fr"][rows].strip() + end + "\n"
            # string += string
            
            with open("./datasets/en-fr.txt", 'a') as file: file.write(string)
            rows += 1
        except:
            rows += 1
    print(rows)
    # rows += data.shape[0]
    data = next(df)
# Out:
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000

# %%
data["fr"][2000]
# Out:
# 'Y a rien à faire.'

# %%
rows
# Out:
# 1000000

# %%
with open("./datasets/en-fr.txt", 'w') as file: file.write(string)
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# Cell In[111], line 1
# ----> 1 with open("./datasets/en-fr.txt", 'w') as file: file.write(string)
#
# MemoryError:

# %%
y = False
for i in data:
    print(i)
    if(y):
        y = not y
        break
# Out:
# en
# fr

# %%
for i in data["en"]:
    print(i)
# Out:
# In 1981, he founded the Astronomy Club of Rimouski in Quebec.
# The club was very active and they twice organized the annual conference of the Amateur Astronomy Federation of Quebec in 1990 and 1997.
# In 1983, Lemay initiated the first joint meeting of the Royal Astronomical Society of Canada, the Amateur Astronomy Federation of Quebec, and the American Association of Variable Star Observers.
# The conference took place in Quebec City, and with over 200 participants it was deemed an unequivocal success.
# From 1990 to 1992, he was the National President of the Royal Astronomical Society of Canada.
# From 1992 to 2000, he was Codirector, with R. Hawkes, of the Canadian Fireball Reporting Centre.
# The centre operates from Mount Allison University in New Brunswick, and collects statistical data about falling stars that appear over Canadian skies.
# The primary goal is to help recover meteorites in the short and long term.
# ...

# %%
import torch.nn as nn
import torch

# %%
linear = nn.Linear(3, 2)

# %%
x = torch.tensor([[0.,1.],[2.,3.],[4.,5.]])

# %%
linear(x)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[134], line 1
# ----> 1 linear(x)
#
# File c:\Users\straw\AppData\Local\Programs\Python\Python311\Lib\site-packages\torch\nn\modules\module.py:1518, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1516     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1517 else:
# -> 1518     return self._call_impl(*args, **kwargs)
#
# File c:\Users\straw\AppData\Local\Programs\Python\Python311\Lib\site-packages\torch\nn\modules\module.py:1527, in Module._call_impl(self, *args, **kwargs)
#    1522 # If we don't have any hooks, we want to skip the rest of the logic in
#    1523 # this function, and just call forward.
#    1524 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
# ...
